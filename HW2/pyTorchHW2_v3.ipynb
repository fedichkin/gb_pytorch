# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
import torch.nn.functional as F
from torch import nn
from torch import optim
import torchvision
import torchvision.transforms as transforms

# %% [markdown]
# Загрузим данные на каких будем тренироваться и тестировать

# %%
train_dataset = torchvision.datasets.CIFAR10(root='data/',
                                             train=True,  
                                             transform=transforms.ToTensor(), 
                                             download=True)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to data/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting data/cifar-10-python.tar.gz to data/

# %%
image, label = train_dataset[0]
print(image.size())
print(label)
# Out:
# torch.Size([3, 32, 32])
# 6

# %%
plt.imshow(image.permute(1, 2, 0).numpy())

# %%
train_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                           batch_size=64, 
                                           shuffle=True)

# %%
test_dataset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                            download=True, transform=transforms.ToTensor())
# Out:
# Files already downloaded and verified

# %%
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=8,
                                          shuffle=False)

# %%
classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

# %% [markdown]
# Создадим класс для нашей модели и предусмотрим возможность менять параметры модели через входящие параметры:
# - количество скрытых слоёв
# - количество входящих нейронов
# - количество нейронов на скрытом слое (по сути это коэфициент, на каждом слое будет разное количество нейронов)
# - количество нейронов на выходном слое

# %%
class Net(nn.Module):
    def __init__(self, count_hidden, input_dim, hidden_dim, output_dim):
        super().__init__()
        self.fc = nn.ModuleList()

        self.fc.append(nn.Linear(input_dim, count_hidden * hidden_dim))

        for index in range(count_hidden - 1, 0, -1):
          self.fc.append(nn.Linear((index + 1) * hidden_dim, index * hidden_dim))

        self.fc.append(nn.Linear(hidden_dim, output_dim))

    def forward(self, x):
        x = x.view(x.shape[0], -1)

        for fc in self.fc:
          x = fc(x)
          x = F.leaky_relu(x)

        return x
    
    def predict(self, x):
        x = x.view(x.shape[0], -1)
        
        for fc in self.fc:
          x = fc(x)
          x = F.leaky_relu(x)

        x = F.softmax(x)
        return x

# %% [markdown]
# Вынесем постоянные параметры сети в константы и напишем функцию которая будет принимать на вход параметры для обучения

# %%
INPUT_DIM = 3 * 32 * 32
OUTPUT_DIM = len(classes)
NUM_EPOCHS = 30 

best_params = {}
best_accuracy = 0

# сюда будем собирать аналитику качества по каждому параметру при одинаковых других параметрах 
analytics = {"num_hidden_layers": {}, "hidden_dim": {}, "fn_optim": {}, "lr": {}}

# %%
def search(num_hidden_layers, hidden_dim, fn_optim, lr):
  global best_accuracy
  global best_params
  global analytics

  print("/-----------------------------------------------------------------------------/")
  print(f"hiddenLayers: {num_hidden_layers}")
  print(f"hiddenDim: {hidden_dim}")
  print(f"fn_optim: {str(fn_optim)}")
  print(f"lr: {lr}")
  print()

  net = Net(num_hidden_layers, INPUT_DIM, hidden_dim, OUTPUT_DIM)
  net.train()

  criterion = nn.CrossEntropyLoss()
  optimizer = fn_optim(net.parameters(), lr=lr)

  for epoch in range(NUM_EPOCHS):
    running_loss = 0.0
    running_items = 0.0


    for i, data in enumerate(train_loader):
        inputs, labels = data[0], data[1]

         # Обнуляем градиент
        optimizer.zero_grad()
        # Делаем предсказание
        outputs = net(inputs)
        # Рассчитываем лосс-функцию
        loss = criterion(outputs, labels)
        # Делаем шаг назад по лоссу
        loss.backward()
        # Делаем шаг нашего оптимайзера
        optimizer.step()

        # выводим статистику о процессе обучения
        running_loss += loss.item()
        running_items += len(labels)

    print(f"Epoch [{epoch + 1}]: Loss: {running_loss / running_items:.3f}")
    running_loss, running_items = 0.0, 0.0

  print('Training is finished!')

  data_iter = iter(test_loader)
  images, labels = data_iter.next()

  net.eval()
  outputs = net(images)

  _, predicted = torch.max(outputs, 1)

  gt = np.array([classes[labels[j]] for j in range(len(labels))])
  pred = np.array([classes[predicted[j]] for j in range(len(labels))])
  accuracy = (gt == pred).sum() / len(gt)

  if accuracy > best_accuracy:
    best_accuracy = accuracy
    best_params = {"hiddenLayers": num_hidden_layers, "hiddenDim": hidden_dim, "fn_optim": str(fn_optim), "lr": lr}

  print(gt)
  print(pred)
  print(f'Accuracy is {accuracy}')

  # собираем аналитику
  key_for_num_hidden_layers = f"{hidden_dim}-{str(fn_optim)}-{lr}"
  key_for_hidden_dim = f"{num_hidden_layers}-{str(fn_optim)}-{lr}"
  key_for_fn_optim = f"{num_hidden_layers}-{hidden_dim}-{lr}"
  key_for_lr = f"{num_hidden_layers}-{hidden_dim}-{str(fn_optim)}"
  
  if key_for_num_hidden_layers not in analytics["num_hidden_layers"]:
      analytics["num_hidden_layers"][key_for_num_hidden_layers] = {
          "params": {"hidden_dim": hidden_dim, "fn_optim": str(fn_optim), "lr": lr},
          "accuracies": []
      }
  
  if key_for_hidden_dim not in analytics["hidden_dim"]:
      analytics["hidden_dim"][key_for_hidden_dim] = {
          "params": {"num_hidden_layers": num_hidden_layers, "fn_optim": str(fn_optim), "lr": lr},
          "accuracies": []
      }
      
  if key_for_fn_optim not in analytics["fn_optim"]:
      analytics["fn_optim"][key_for_fn_optim] = {
          "params": {"num_hidden_layers": num_hidden_layers, "hidden_dim": hidden_dim, "lr": lr},
          "accuracies": []
      }
  
  if key_for_lr not in analytics["lr"]:
      analytics["lr"][key_for_lr] = {
          "params": {"num_hidden_layers": num_hidden_layers, "hidden_dim": hidden_dim, "fn_optim": str(fn_optim)},
          "accuracies": []
      }
  
  analytics["hidden_dim"][key_for_hidden_dim]["accuracies"].append(accuracy)
  analytics["fn_optim"][key_for_fn_optim]["accuracies"].append(accuracy)
  analytics["num_hidden_layers"][key_for_num_hidden_layers]["accuracies"].append(accuracy)
  analytics["lr"][key_for_lr]["accuracies"].append(accuracy)

# %% [markdown]
# Определим массивы параметров для поиска

# %%
hidden_layers = [1, 2, 3, 5]
hidden_dims = [10, 50, 100]
lrs = [0.01, 0.001]
optims = [optim.SGD, optim.Adam, optim.NAdam]

# %% [markdown]
# Запускаем обучение модели с разными параметрами. В процечче будет собрана аналитика

# %%
for num_layers in hidden_layers:
  for hidden_dim in hidden_dims:
     for lr in lrs:
       for fn_optim in optims:
         search(num_layers, hidden_dim, fn_optim, lr)
# Out:
# /-----------------------------------------------------------------------------/
# hiddenLayers: 1
# hiddenDim: 10
# fn_optim: <class 'torch.optim.sgd.SGD'>
# lr: 0.01
#
# Epoch [1]: Loss: 0.034
# Epoch [2]: Loss: 0.032
# Epoch [3]: Loss: 0.031
# Epoch [4]: Loss: 0.030
# Epoch [5]: Loss: 0.029
# Epoch [6]: Loss: 0.029
# Epoch [7]: Loss: 0.028
# Epoch [8]: Loss: 0.028
# Epoch [9]: Loss: 0.028
# Epoch [10]: Loss: 0.027
# Epoch [11]: Loss: 0.027
# Epoch [12]: Loss: 0.027
# Epoch [13]: Loss: 0.027
# Epoch [14]: Loss: 0.027
# Epoch [15]: Loss: 0.027
# Epoch [16]: Loss: 0.027
'fn_optim': "<class 'torch.optim.adam.Adam'>",
#  'hiddenDim': 50,
#  'hiddenLayers': 1,
#  'lr': 0.01}

# %%
analytics
# Out:
# {'fn_optim': {'1-10-0.001': {'accuracies': [0.25, 0.5, 0.625],
#    'params': {'hidden_dim': 10, 'lr': 0.001, 'num_hidden_layers': 1}},
#   '1-10-0.01': {'accuracies': [0.5, 0.5, 0.5],
#    'params': {'hidden_dim': 10, 'lr': 0.01, 'num_hidden_layers': 1}},
#   '1-100-0.001': {'accuracies': [0.375, 0.625, 0.625],
#    'params': {'hidden_dim': 100, 'lr': 0.001, 'num_hidden_layers': 1}},
#   '1-100-0.01': {'accuracies': [0.75, 0.25, 0.375],
#    'params': {'hidden_dim': 100, 'lr': 0.01, 'num_hidden_layers': 1}},
#   '1-50-0.001': {'accuracies': [0.375, 0.5, 0.625],
#    'params': {'hidden_dim': 50, 'lr': 0.001, 'num_hidden_layers': 1}},
#   '1-50-0.01': {'accuracies': [0.5, 0.75, 0.5],
#    'params': {'hidden_dim': 50, 'lr': 0.01, 'num_hidden_layers': 1}},
#   '2-10-0.001': {'accuracies': [0.5, 0.5, 0.75],
#    'params': {'hidden_dim': 10, 'lr': 0.001, 'num_hidden_layers': 2}},
#   '2-10-0.01': {'accuracies': [0.5, 0.5, 0.625],
#    'params': {'hidden_dim': 10, 'lr': 0.01, 'num_hidden_layers': 2}},
#   '2-100-0.001': {'accuracies': [0.375, 0.5, 0.625],
#    'params': {'hidden_dim': 100, 'lr': 0.001, 'num_hidden_layers': 2}},
#   '2-100-0.01': {'accuracies': [0.5, 0.75, 0.5],
#    'params': {'hidden_dim': 100, 'lr': 0.01, 'num_hidden_layers': 2}},
#   '2-50-0.001': {'accuracies': [0.125, 0.75, 0.5],
#    'params': {'hidden_dim': 50, 'lr': 0.001, 'num_hidden_layers': 2}},
#   '2-50-0.01': {'accuracies': [0.5, 0.625, 0.75],
#    'params': {'hidden_dim': 50, 'lr': 0.01, 'num_hidden_layers': 2}},
#   '3-10-0.001': {'accuracies': [0.0, 0.5, 0.5],
#    'params': {'hidden_dim': 10, 'lr': 0.001, 'num_hidden_layers': 3}},
#   '3-10-0.01': {'accuracies': [0.625, 0.5, 0.5],
#    'params': {'hidden_dim': 10, 'lr': 0.01, 'num_hidden_layers': 3}},
#   '3-100-0.001': {'accuracies': [0.5, 0.375, 0.75],
#    'params': {'hidden_dim': 100, 'lr': 0.001, 'num_hidden_layers': 3}},
#   '3-100-0.01': {'accuracies': [0.5, 0.5, 0.375],
#    'params': {'hidden_dim': 100, 'lr': 0.01, 'num_hidden_layers': 3}},
#   '3-50-0.001': {'accuracies': [0.25, 0.5, 0.625],
#    'params': {'hidden_dim': 50, 'lr': 0.001, 'num_hidden_layers': 3}},
#   '3-50-0.01': {'accuracies': [0.375, 0.5, 0.375],
#    'params': {'hidden_dim': 50, 'lr': 0.01, 'num_hidden_layers': 3}},
#   '5-10-0.001': {'accuracies': [0.0, 0.75, 0.5],
#    'params': {'hidden_dim': 10, 'lr': 0.001, 'num_hidden_layers': 5}},
#   '5-10-0.01': {'accuracies': [0.0, 0.25, 0.25],
#    'params': {'hidden_dim': 10, 'lr': 0.01, 'num_hidden_layers': 5}},
#   '5-100-0.001': {'accuracies': [0.0, 0.75, 0.625],
#    'params': {'hidden_dim': 100, 'lr': 0.001, 'num_hidden_layers': 5}},
#   '5-100-0.01': {'accuracies': [0.75, 0.25, 0.125],
#    'params': {'hidden_dim': 100, 'lr': 0.01, 'num_hidden_layers': 5}},
#   '5-50-0.001': {'accuracies': [0.625, 0.5, 0.375],
#    'params': {'hidden_dim': 50, 'lr': 0.001, 'num_hidden_layers': 5}},
#   '5-50-0.01': {'accuracies': [0.75, 0.375, 0.25],
#    'params': {'hidden_dim': 50, 'lr': 0.01, 'num_hidden_layers': 5}}},
#  'hidden_dim': {"1-<class 'torch.optim.adam.Adam'>-0.001": {'accuracies': [0.5,
#     0.5,
#     0.625],
#    'params': {'fn_optim': "<class 'torch.optim.adam.Adam'>",
#     'lr': 0.001,
#     'num_hidden_layers': 1}},
#   "1-<class 'torch.optim.adam.Adam'>-0.01": {'accuracies': [0.5, 0.75, 0.25],
#    'params': {'fn_optim': "<class 'torch.optim.adam.Adam'>",
#     'lr': 0.01,
#     'num_hidden_layers': 1}},
#   "1-<class 'torch.optim.nadam.NAdam'>-0.001": {'accuracies': [0.625,
#     0.625,
#     0.625],
#    'params': {'fn_optim': "<class 'torch.optim.nadam.NAdam'>",
#     'lr': 0.001,
#     'num_hidden_layers': 1}},
#   "1-<class 'torch.optim.nadam.NAdam'>-0.01": {'accuracies': [0.5, 0.5, 0.375],
#    'params': {'fn_optim': "<class 'torch.optim.nadam.NAdam'>",
#     'lr': 0.01,
#     'num_hidden_layers': 1}},
#   "1-<class 'torch.optim.sgd.SGD'>-0.001": {'accuracies': [0.25, 0.375, 0.375],
#    'params': {'fn_optim': "<class 'torch.optim.sgd.SGD'>",
#     'lr': 0.001,
#     'num_hidden_layers': 1}},
#   "1-<class 'torch.optim.sgd.SGD'>-0.01": {'accuracies': [0.5, 0.5, 0.75],
#    'params': {'fn_optim': "<class 'torch.optim.sgd.SGD'>",
#     'lr': 0.01,
#     'num_hidden_layers': 1}},
#   "2-<class 'torch.optim.adam.Adam'>-0.001": {'accuracies': [0.5, 0.75, 0.5],
#    'params': {'fn_optim': "<class 'torch.optim.adam.Adam'>",
#     'lr': 0.001,
#     'num_hidden_layers': 2}},
#   "2-<class 'torch.optim.adam.Adam'>-0.01": {'accuracies': [0.5, 0.625, 0.75],
#    'params': {'fn_optim': "<class 'torch.optim.adam.Adam'>",
#     'lr': 0.01,
#     'num_hidden_layers': 2}},
#   "2-<class 'torch.optim.nadam.NAdam'>-0.001": {'accuracies': [0.75,
#     0.5,
#     0.625],
#    'params': {'fn_optim': "<class 'torch.optim.nadam.NAdam'>",
#     'lr': 0.001,
#     'num_hidden_layers': 2}},
#   "2-<class 'torch.optim.nadam.NAdam'>-0.01": {'accuracies': [0.625,
#     0.75,
#     0.5],
#    'params': {'fn_optim': "<class 'torch.optim.nadam.NAdam'>",
#     'lr': 0.01,
#     'num_hidden_layers': 2}},
#   "2-<class 'torch.optim.sgd.SGD'>-0.001": {'accuracies': [0.5, 0.125, 0.375],
#    'params': {'fn_optim': "<class 'torch.optim.sgd.SGD'>",
#     'lr': 0.001,
#     'num_hidden_layers': 2}},
#   "2-<class 'torch.optim.sgd.SGD'>-0.01": {'accuracies': [0.5, 0.5, 0.5],
#    'params': {'fn_optim': "<class 'torch.optim.sgd.SGD'>",
#     'lr': 0.01,
#     'num_hidden_layers': 2}},
#   "3-<class 'torch.optim.adam.Adam'>-0.001": {'accuracies': [0.5, 0.5, 0.375],
#    'params': {'fn_optim': "<class 'torch.optim.adam.Adam'>",
#     'lr': 0.001,
#     'num_hidden_layers': 3}},
#   "3-<class 'torch.optim.adam.Adam'>-0.01": {'accuracies': [0.5, 0.5, 0.5],
#    'params': {'fn_optim': "<class 'torch.optim.adam.Adam'>",
#     'lr': 0.01,
#     'num_hidden_layers': 3}},
#   "3-<class 'torch.optim.nadam.NAdam'>-0.001": {'accuracies': [0.5,
#     0.625,
#     0.75],
#    'params': {'fn_optim': "<class 'torch.optim.nadam.NAdam'>",
#     'lr': 0.001,
#     'num_hidden_layers': 3}},
#   "3-<class 'torch.optim.nadam.NAdam'>-0.01": {'accuracies': [0.5,
#     0.375,
#     0.375],
#    'params': {'fn_optim': "<class 'torch.optim.nadam.NAdam'>",
#     'lr': 0.01,
#     'num_hidden_layers': 3}},
#   "3-<class 'torch.optim.sgd.SGD'>-0.001": {'accuracies': [0.0, 0.25, 0.5],
#    'params': {'fn_optim': "<class 'torch.optim.sgd.SGD'>",
#     'lr': 0.001,
#     'num_hidden_layers': 3}},
#   "3-<class 'torch.optim.sgd.SGD'>-0.01": {'accuracies': [0.625, 0.375, 0.5],
#    'params': {'fn_optim': "<class 'torch.optim.sgd.SGD'>",
#     'lr': 0.01,
#     'num_hidden_layers': 3}},
#   "5-<class 'torch.optim.adam.Adam'>-0.001": {'accuracies': [0.75, 0.5, 0.75],
#    'params': {'fn_optim': "<class 'torch.optim.adam.Adam'>",
#     'lr': 0.001,
#     'num_hidden_layers': 5}},
#   "5-<class 'torch.optim.adam.Adam'>-0.01": {'accuracies': [0.25, 0.375, 0.25],
#    'params': {'fn_optim': "<class 'torch.optim.adam.Adam'>",
#     'lr': 0.01,
#     'num_hidden_layers': 5}},
#   "5-<class 'torch.optim.nadam.NAdam'>-0.001": {'accuracies': [0.5,
#     0.375,
#     0.625],
#    'params': {'fn_optim': "<class 'torch.optim.nadam.NAdam'>",
#     'lr': 0.001,
#     'num_hidden_layers': 5}},
#   "5-<class 'torch.optim.nadam.NAdam'>-0.01": {'accuracies': [0.25,
#     0.25,
#     0.125],
#    'params': {'fn_optim': "<class 'torch.optim.nadam.NAdam'>",
#     'lr': 0.01,
#     'num_hidden_layers': 5}},
#   "5-<class 'torch.optim.sgd.SGD'>-0.001": {'accuracies': [0.0, 0.625, 0.0],
#    'params': {'fn_optim': "<class 'torch.optim.sgd.SGD'>",
#     'lr': 0.001,
#     'num_hidden_layers': 5}},
#   "5-<class 'torch.optim.sgd.SGD'>-0.01": {'accuracies': [0.0, 0.75, 0.75],
#    'params': {'fn_optim': "<class 'torch.optim.sgd.SGD'>",
#     'lr': 0.01,
#     'num_hidden_layers': 5}}},
#  'lr': {"1-10-<class 'torch.optim.adam.Adam'>": {'accuracies': [0.5, 0.5],
#    'params': {'fn_optim': "<class 'torch.optim.adam.Adam'>",
#     'hidden_dim': 10,
#     'num_hidden_layers': 1}},
#   "1-10-<class 'torch.optim.nadam.NAdam'>": {'accuracies': [0.5, 0.625],
#    'params': {'fn_optim': "<class 'torch.optim.nadam.NAdam'>",
#     'hidden_dim': 10,
#     'num_hidden_layers': 1}},
#   "1-10-<class 'torch.optim.sgd.SGD'>": {'accuracies': [0.5, 0.25],
#    'params': {'fn_optim': "<class 'torch.optim.sgd.SGD'>",
#     'hidden_dim': 10,
#     'num_hidden_layers': 1}},
#   "1-100-<class 'torch.optim.adam.Adam'>": {'accuracies': [0.25, 0.625],
#    'params': {'fn_optim': "<class 'torch.optim.adam.Adam'>",
#     'hidden_dim': 100,
#     'num_hidden_layers': 1}},
#   "1-100-<class 'torch.optim.nadam.NAdam'>": {'accuracies': [0.375, 0.625],
#    'params': {'fn_optim': "<class 'torch.optim.nadam.NAdam'>",
#     'hidden_dim': 100,
#     'num_hidden_layers': 1}},
#   "1-100-<class 'torch.optim.sgd.SGD'>": {'accuracies': [0.75, 0.375],
#    'params': {'fn_optim': "<class 'torch.optim.sgd.SGD'>",
#     'hidden_dim': 100,
#     'num_hidden_layers': 1}},
#   "1-50-<class 'torch.optim.adam.Adam'>": {'accuracies': [0.75, 0.5],
#    'params': {'fn_optim': "<class 'torch.optim.adam.Adam'>",
#     'hidden_dim': 50,
#     'num_hidden_layers': 1}},
#   "1-50-<class 'torch.optim.nadam.NAdam'>": {'accuracies': [0.5, 0.625],
#    'params': {'fn_optim': "<class 'torch.optim.nadam.NAdam'>",
#     'hidden_dim': 50,
#     'num_hidden_layers': 1}},
#   "1-50-<class 'torch.optim.sgd.SGD'>": {'accuracies': [0.5, 0.375],
#    'params': {'fn_optim': "<class 'torch.optim.sgd.SGD'>",
#     'hidden_dim': 50,
#     'num_hidden_layers': 1}},
#   "2-10-<class 'torch.optim.adam.Adam'>": {'accuracies': [0.5, 0.5],
#    'params': {'fn_optim': "<class 'torch.optim.adam.Adam'>",
#     'hidden_dim': 10,
#     'num_hidden_layers': 2}},
#   "2-10-<class 'torch.optim.nadam.NAdam'>": {'accuracies': [0.625, 0.75],
#    'params': {'fn_optim': "<class 'torch.optim.nadam.NAdam'>",
#     'hidden_dim': 10,
#     'num_hidden_layers': 2}},
#   "2-10-<class 'torch.optim.sgd.SGD'>": {'accuracies': [0.5, 0.5],
#    'params': {'fn_optim': "<class 'torch.optim.sgd.SGD'>",
#     'hidden_dim': 10,
#     'num_hidden_layers': 2}},
#   "2-100-<class 'torch.optim.adam.Adam'>": {'accuracies': [0.75, 0.5],
#    'params': {'fn_optim': "<class 'torch.optim.adam.Adam'>",
#     'hidden_dim': 100,
#     'num_hidden_layers': 2}},
#   "2-100-<class 'torch.optim.nadam.NAdam'>": {'accuracies': [0.5, 0.625],
#    'params': {'fn_optim': "<class 'torch.optim.nadam.NAdam'>",
#     'hidden_dim': 100,
#     'num_hidden_layers': 2}},
#   "2-100-<class 'torch.optim.sgd.SGD'>": {'accuracies': [0.5, 0.375],
#    'params': {'fn_optim': "<class 'torch.optim.sgd.SGD'>",
#     'hidden_dim': 100,
#     'num_hidden_layers': 2}},
#   "2-50-<class 'torch.optim.adam.Adam'>": {'accuracies': [0.625, 0.75],
#    'params': {'fn_optim': "<class 'torch.optim.adam.Adam'>",
#     'hidden_dim': 50,
#     'num_hidden_layers': 2}},
#   "2-50-<class 'torch.optim.nadam.NAdam'>": {'accuracies': [0.75, 0.5],
#    'params': {'fn_optim': "<class 'torch.optim.nadam.NAdam'>",
#     'hidden_dim': 50,
#     'num_hidden_layers': 2}},
#   "2-50-<class 'torch.optim.sgd.SGD'>": {'accuracies': [0.5, 0.125],
#    'params': {'fn_optim': "<class 'torch.optim.sgd.SGD'>",
#     'hidden_dim': 50,
#     'num_hidden_layers': 2}},
#   "3-10-<class 'torch.optim.adam.Adam'>": {'accuracies': [0.5, 0.5],
#    'params': {'fn_optim': "<class 'torch.optim.adam.Adam'>",
#     'hidden_dim': 10,
#     'num_hidden_layers': 3}},
#   "3-10-<class 'torch.optim.nadam.NAdam'>": {'accuracies': [0.5, 0.5],
#    'params': {'fn_optim': "<class 'torch.optim.nadam.NAdam'>",
#     'hidden_dim': 10,
#     'num_hidden_layers': 3}},
#   "3-10-<class 'torch.optim.sgd.SGD'>": {'accuracies': [0.625, 0.0],
#    'params': {'fn_optim': "<class 'torch.optim.sgd.SGD'>",
#     'hidden_dim': 10,
#     'num_hidden_layers': 3}},
#   "3-100-<class 'torch.optim.adam.Adam'>": {'accuracies': [0.5, 0.375],
#    'params': {'fn_optim': "<class 'torch.optim.adam.Adam'>",
#     'hidden_dim': 100,
#     'num_hidden_layers': 3}},
#   "3-100-<class 'torch.optim.nadam.NAdam'>": {'accuracies': [0.375, 0.75],
#    'params': {'fn_optim': "<class 'torch.optim.nadam.NAdam'>",
#     'hidden_dim': 100,
#     'num_hidden_layers': 3}},
#   "3-100-<class 'torch.optim.sgd.SGD'>": {'accuracies': [0.5, 0.5],
#    'params': {'fn_optim': "<class 'torch.optim.sgd.SGD'>",
#     'hidden_dim': 100,
#     'num_hidden_layers': 3}},
#   "3-50-<class 'torch.optim.adam.Adam'>": {'accuracies': [0.5, 0.5],
#    'params': {'fn_optim': "<class 'torch.optim.adam.Adam'>",
#     'hidden_dim': 50,
#     'num_hidden_layers': 3}},
#   "3-50-<class 'torch.optim.nadam.NAdam'>": {'accuracies': [0.375, 0.625],
#    'params': {'fn_optim': "<class 'torch.optim.nadam.NAdam'>",
#     'hidden_dim': 50,
#     'num_hidden_layers': 3}},
#   "3-50-<class 'torch.optim.sgd.SGD'>": {'accuracies': [0.375, 0.25],
#    'params': {'fn_optim': "<class 'torch.optim.sgd.SGD'>",
#     'hidden_dim': 50,
#     'num_hidden_layers': 3}},
#   "5-10-<class 'torch.optim.adam.Adam'>": {'accuracies': [0.25, 0.75],
#    'params': {'fn_optim': "<class 'torch.optim.adam.Adam'>",
#     'hidden_dim': 10,
#     'num_hidden_layers': 5}},
#   "5-10-<class 'torch.optim.nadam.NAdam'>": {'accuracies': [0.25, 0.5],
#    'params': {'fn_optim': "<class 'torch.optim.nadam.NAdam'>",
#     'hidden_dim': 10,
#     'num_hidden_layers': 5}},
#   "5-10-<class 'torch.optim.sgd.SGD'>": {'accuracies': [0.0, 0.0],
#    'params': {'fn_optim': "<class 'torch.optim.sgd.SGD'>",
#     'hidden_dim': 10,
#     'num_hidden_layers': 5}},
#   "5-100-<class 'torch.optim.adam.Adam'>": {'accuracies': [0.25, 0.75],
#    'params': {'fn_optim': "<class 'torch.optim.adam.Adam'>",
#     'hidden_dim': 100,
#     'num_hidden_layers': 5}},
#   "5-100-<class 'torch.optim.nadam.NAdam'>": {'accuracies': [0.125, 0.625],
#    'params': {'fn_optim': "<class 'torch.optim.nadam.NAdam'>",
#     'hidden_dim': 100,
#     'num_hidden_layers': 5}},
#   "5-100-<class 'torch.optim.sgd.SGD'>": {'accuracies': [0.75, 0.0],
#    'params': {'fn_optim': "<class 'torch.optim.sgd.SGD'>",
#     'hidden_dim': 100,
#     'num_hidden_layers': 5}},
#   "5-50-<class 'torch.optim.adam.Adam'>": {'accuracies': [0.375, 0.5],
#    'params': {'fn_optim': "<class 'torch.optim.adam.Adam'>",
#     'hidden_dim': 50,
#     'num_hidden_layers': 5}},
#   "5-50-<class 'torch.optim.nadam.NAdam'>": {'accuracies': [0.25, 0.375],
#    'params': {'fn_optim': "<class 'torch.optim.nadam.NAdam'>",
#     'hidden_dim': 50,
#     'num_hidden_layers': 5}},
#   "5-50-<class 'torch.optim.sgd.SGD'>": {'accuracies': [0.75, 0.625],
#    'params': {'fn_optim': "<class 'torch.optim.sgd.SGD'>",
#     'hidden_dim': 50,
#     'num_hidden_layers': 5}}},
#  'num_hidden_layers': {"10-<class 'torch.optim.adam.Adam'>-0.001": {'accuracies': [0.5,
#     0.5,
#     0.5,
#     0.75],
#    'params': {'fn_optim': "<class 'torch.optim.adam.Adam'>",
#     'hidden_dim': 10,
#     'lr': 0.001}},
#   "10-<class 'torch.optim.adam.Adam'>-0.01": {'accuracies': [0.5,
#     0.5,
#     0.5,
#     0.25],
#    'params': {'fn_optim': "<class 'torch.optim.adam.Adam'>",
#     'hidden_dim': 10,
#     'lr': 0.01}},
#   "10-<class 'torch.optim.nadam.NAdam'>-0.001": {'accuracies': [0.625,
#     0.75,
#     0.5,
#     0.5],
#    'params': {'fn_optim': "<class 'torch.optim.nadam.NAdam'>",
#     'hidden_dim': 10,
#     'lr': 0.001}},
#   "10-<class 'torch.optim.nadam.NAdam'>-0.01": {'accuracies': [0.5,
#     0.625,
#     0.5,
#     0.25],
#    'params': {'fn_optim': "<class 'torch.optim.nadam.NAdam'>",
#     'hidden_dim': 10,
#     'lr': 0.01}},
#   "10-<class 'torch.optim.sgd.SGD'>-0.001": {'accuracies': [0.25,
#     0.5,
#     0.0,
#     0.0],
#    'params': {'fn_optim': "<class 'torch.optim.sgd.SGD'>",
#     'hidden_dim': 10,
#     'lr': 0.001}},
#   "10-<class 'torch.optim.sgd.SGD'>-0.01": {'accuracies': [0.5,
#     0.5,
#     0.625,
#     0.0],
#    'params': {'fn_optim': "<class 'torch.optim.sgd.SGD'>",
#     'hidden_dim': 10,
#     'lr': 0.01}},
#   "100-<class 'torch.optim.adam.Adam'>-0.001": {'accuracies': [0.625,
#     0.5,
#     0.375,
#     0.75],
#    'params': {'fn_optim': "<class 'torch.optim.adam.Adam'>",
#     'hidden_dim': 100,
#     'lr': 0.001}},
#   "100-<class 'torch.optim.adam.Adam'>-0.01": {'accuracies': [0.25,
#     0.75,
#     0.5,
#     0.25],
#    'params': {'fn_optim': "<class 'torch.optim.adam.Adam'>",
#     'hidden_dim': 100,
#     'lr': 0.01}},
#   "100-<class 'torch.optim.nadam.NAdam'>-0.001": {'accuracies': [0.625,
#     0.625,
#     0.75,
#     0.625],
#    'params': {'fn_optim': "<class 'torch.optim.nadam.NAdam'>",
#     'hidden_dim': 100,
#     'lr': 0.001}},
#   "100-<class 'torch.optim.nadam.NAdam'>-0.01": {'accuracies': [0.375,
#     0.5,
#     0.375,
#     0.125],
#    'params': {'fn_optim': "<class 'torch.optim.nadam.NAdam'>",
#     'hidden_dim': 100,
#     'lr': 0.01}},
#   "100-<class 'torch.optim.sgd.SGD'>-0.001": {'accuracies': [0.375,
#     0.375,
#     0.5,
#     0.0],
#    'params': {'fn_optim': "<class 'torch.optim.sgd.SGD'>",
#     'hidden_dim': 100,
#     'lr': 0.001}},
#   "100-<class 'torch.optim.sgd.SGD'>-0.01": {'accuracies': [0.75,
#     0.5,
#     0.5,
#     0.75],
#    'params': {'fn_optim': "<class 'torch.optim.sgd.SGD'>",
#     'hidden_dim': 100,
#     'lr': 0.01}},
#   "50-<class 'torch.optim.adam.Adam'>-0.001": {'accuracies': [0.5,
#     0.75,
#     0.5,
#     0.5],
#    'params': {'fn_optim': "<class 'torch.optim.adam.Adam'>",
#     'hidden_dim': 50,
#     'lr': 0.001}},
#   "50-<class 'torch.optim.adam.Adam'>-0.01": {'accuracies': [0.75,
#     0.625,
#     0.5,
#     0.375],
#    'params': {'fn_optim': "<class 'torch.optim.adam.Adam'>",
#     'hidden_dim': 50,
#     'lr': 0.01}},
#   "50-<class 'torch.optim.nadam.NAdam'>-0.001": {'accuracies': [0.625,
#     0.5,
#     0.625,
#     0.375],
#    'params': {'fn_optim': "<class 'torch.optim.nadam.NAdam'>",
#     'hidden_dim': 50,
#     'lr': 0.001}},
#   "50-<class 'torch.optim.nadam.NAdam'>-0.01": {'accuracies': [0.5,
#     0.75,
#     0.375,
#     0.25],
#    'params': {'fn_optim': "<class 'torch.optim.nadam.NAdam'>",
#     'hidden_dim': 50,
#     'lr': 0.01}},
#   "50-<class 'torch.optim.sgd.SGD'>-0.001": {'accuracies': [0.375,
#     0.125,
#     0.25,
#     0.625],
#    'params': {'fn_optim': "<class 'torch.optim.sgd.SGD'>",
#     'hidden_dim': 50,
#     'lr': 0.001}},
#   "50-<class 'torch.optim.sgd.SGD'>-0.01": {'accuracies': [0.5,
#     0.5,
#     0.375,
#     0.75],
#    'params': {'fn_optim': "<class 'torch.optim.sgd.SGD'>",
#     'hidden_dim': 50,
#     'lr': 0.01}}}}

# %%
def show_graph_by_accuracy(accaracies, x_params, x_label, title):
    plt.figure(figsize = (8,5))
    plt.plot(x_params, accaracies)
    plt.xlabel(x_label)
    plt.ylabel("Accuracy")
    plt.title(title)
    plt.grid()
    plt.show()

# %% [markdown]
# Расмотрим результат собранной аналитики

# %%
for key in analytics["num_hidden_layers"]:
    num_hidden_layers_analitic = analytics["num_hidden_layers"][key]
    accuracies = num_hidden_layers_analitic["accuracies"]
    params = num_hidden_layers_analitic["params"]
    
    show_graph_by_accuracy(
        accuracies, 
        hidden_layers, 
        "Количество скрытых слоев", 
        f"Зависимость качества от количества скрытых слоев (Параметры: {params})"
    )

# %% [markdown]
# Количество скрытых слоев влияет на качество обучения. Самые лучшие результаты достигаются при 1, 2 или 3 слоях. Есть хорошие результаты и при пяти, но редко. Основной вывод: при большом количестве скрытых слоев должно бвть много нейронов и подходящий оптимизатор

# %%
for key in analytics["hidden_dim"]:
    hidden_dim_analitic = analytics["hidden_dim"][key]
    accuracies = hidden_dim_analitic["accuracies"]
    params = hidden_dim_analitic["params"]
    
    show_graph_by_accuracy(
        accuracies, 
        hidden_dims, 
        "Коэфициент количества нейронов на скрытых слоях", 
        f"Зависимость качества от количества нейронов на скрытых слоях (Параметры: {params})"
    )

# %% [markdown]
# Здесь ситуация следующая: нейронов не должно быть мало, но и слишком много не надо, коэффициент 50 показывает себя лучше всего. Особенно плохо модель себя проявила с маленьким количеством слоёв и большой точностью

# %%
for key in analytics["fn_optim"]:
    optim_analitic = analytics["fn_optim"][key]
    accuracies = optim_analitic["accuracies"]
    params = optim_analitic["params"]
    fn_optims = [str(fn_optim) for fn_optim in optims]
    
    show_graph_by_accuracy(
        accuracies, 
        fn_optims, 
        "Функция оптимизации", 
        f"Зависимость качества от функции оптимизации (Параметры: {params})"
    )

# %% [markdown]
# По функции оптимизации полный разброс, зависит от остальных параметров модели

# %%
for key in analytics["lr"]:
    lr_analitic = analytics["lr"][key]
    accuracies = lr_analitic["accuracies"]
    params = lr_analitic["params"]
    
    show_graph_by_accuracy(
        accuracies, 
        lrs, 
        "Точность", 
        f"Зависимость качества от точности (Параметры: {params})"
    )

# %% [markdown]
# Что касается точности, то в основном значение 0.01 лучше себя проявило, но есть и исключения

# %% [markdown]
# Общий вывод: нужно смотреть модели с тем качеством какое интересует и дальше исследовать их. Для данной задачи не хватает тестовых данных, из-за чего периодические рассчитывается не верное accuracy, когда модель совсем не может предсказывать и выдает только одно значение, то качество может достигать 0.5, что не совсем корректно, так как результат получился совершенно случайно.
